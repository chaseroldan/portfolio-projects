# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Load in csv
df = pd.read_csv("data/top-songs.csv", encoding= 'unicode_escape')
df.head()
# Out:
#                             title  \
# 0            Like a Rolling Stone
# 1  (I Can't Get No) Satisfaction'
# 2                         Imagine
# 3                 What's Going On
# 4                         Respect
#
#                                          description  \
# 0  "I wrote it. I didn't fail. It was straight," ...
# 1  "It's the riff heard round the world," says St...
# 2  John Lennon wrote "Imagine," his greatest musi...
# 3  "What's Going On" is an exquisite plea for pea...
# 4  Otis Redding wrote "Respect" and recorded it f...
#
#                                           appears on              artist  \
# 0                    Highway 61 Revisited (Columbia)           Bob Dylan
# 1                           Out of Our Heads (ABKCO)  The Rolling Stones
# 2                            Imagine (Capitol/Apple)         John Lennon
# 3                            What's Going On (Tamla)         Marvin Gaye
# ...

# %%
# new data frame with split value columns 
new = df["released"].str.split(",", n = 1, expand = True) 
  
# making separate first name column from new data frame 
df["month"]= new[0] 
  
# making separate last name column from new data frame 
df["year"]= new[1] 
  
# Dropping old Name columns 
df.drop(columns =["released"], inplace = True) 
  
# df display 
df
# Out:
#                               title  \
# 0              Like a Rolling Stone
# 1    (I Can't Get No) Satisfaction'
# 2                           Imagine
# 3                   What's Going On
# 4                           Respect
# ..                              ...
# 495                          Heroin
# 496              Leader of the Pack
# 497                   Pressure Drop
# 498                 Come As You Are
# 499                  I Got You Babe
#
#                                            description  \
# 0    "I wrote it. I didn't fail. It was straight," ...
# 1    "It's the riff heard round the world," says St...
# 2    John Lennon wrote "Imagine," his greatest musi...
# 3    "What's Going On" is an exquisite plea for pea...
# 4    Otis Redding wrote "Respect" and recorded it f...
# ..                                                 ...
# 495  This seven-minute, two-chord track spiked out ...
# 496  Morton found the inspiration for this song at ...
# ...

# %%
df = df.drop_duplicates()

# %%
df.to_csv('data/top500.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 450 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        450 non-null    object
#  1   description  450 non-null    object
#  2   appears on   450 non-null    object
#  3   artist       450 non-null    object
#  4   writers      450 non-null    object
#  5   producer     450 non-null    object
#  6   streak       445 non-null    object
#  7   position     356 non-null    object
#  8   month        450 non-null    object
#  9   year         450 non-null    object
# dtypes: object(10)
# memory usage: 38.7+ KB

# %%
# Select a list of songs that streaked at No.1
top_songs_df = df.loc[df["position"] == 'No. 1', :]
top_songs_df.sort_values('artist')
# Out:
#                                   title  \
# 176                       Dancing Queen
# 4                               Respect
# 159                        Stayin Alive
# 191  (Were Gonna) Rock Around the Clock
# 38                   That'll Be the Day
# 44                     Heartbreak Hotel
# 150                       Dont Be Cruel
# 18                            Hound Dog
# 152                   Sweet Child OMine
# 182                      Lets Get It On
# 25     (Sittin' on) the Dock of the Bay
# 168                             Hey Ya!
# 43                   Georgia on My Mind
# 186              I Cant Stop Loving You
# 193               The Sounds of Silence
# 47           Bridge Over Troubled Water
# 185                Nothing Compares 2 U
# 196                   A Hard Days Night
# 28                                Help!
# 19                            Let It Be
# 15             I Want to Hold Your Hand
# 12                            Yesterday
# ...

# %%
top_songs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30 entries, 1 to 196
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        30 non-null     object
#  1   description  30 non-null     object
#  2   appears on   30 non-null     object
#  3   artist       30 non-null     object
#  4   writers      30 non-null     object
#  5   producer     30 non-null     object
#  6   streak       30 non-null     object
#  7   position     30 non-null     object
#  8   month        30 non-null     object
#  9   year         30 non-null     object
# dtypes: object(10)
# memory usage: 2.6+ KB

# %%
artist_df = df['artist'].value_counts()
artist_df.head(25)
# Out:
# The Beatles                     20
# Bob Dylan                       12
# Elvis Presley                   10
# The Rolling Stones              10
# U2                               7
# The Beach Boys                   7
# The Jimi Hendrix Experience      6
# Led Zeppelin                     5
# Chuck Berry                      5
# Ray Charles                      5
# The Clash                        5
# The Four Tops                    4
# Bruce Springsteen                4
# Nirvana                          4
# Elton John                       4
# James Brown                      4
# Marvin Gaye                      4
# The Who                          4
# Sly and the Family Stone         4
# Little Richard                   4
# Roy Orbison                      4
# Creedence Clearwater Revival     4
# The Drifters                     4
# Muddy Waters                     4
# Aretha Franklin                  4
# Name: artist, dtype: int64

# %%
# Select a list of songs by The Beatles
beatles_songs_df = df.loc[df["artist"] == 'The Beatles', :]
beatles_songs_df.head()
# Out:
#                        title  \
# 7                   Hey Jude
# 12                 Yesterday
# 15  I Want to Hold Your Hand
# 19                 Let It Be
# 22                In My Life
#
#                                           description  \
# 7   The Beatles' biggest U.S. single  nine weeks ...
# 12  Paul McCartney's greatest ballad holds a Guinn...
# 15  As a young, struggling beat group, playing gru...
# 19  Inspired by the church-born soul of Aretha Fra...
# 22  "''In My Life' was, I think, my first real, ma...
#
#                             appears on       artist  \
# 7                   1 (Capitol/Apple)   The Beatles
# 12               Help! (Capitol/Apple)  The Beatles
# 15  Meet the Beatles! (Capitol/Apple)   The Beatles
# 19           Let It Be (Capitol/Apple)  The Beatles
# 22              Rubber Soul (Capitol)   The Beatles
#
#                         writers       producer    streak position  month  \
# ...

# %%
dylan_songs_df = df.loc[df["artist"] == 'Bob Dylan', :]
dylan_songs_df.head()
# Out:
#                             title  \
# 0            Like a Rolling Stone
# 13            Blowin' in the Wind
# 82             Tangled Up in Blue
# 91   The Times They Are A-Changin
# 158       Knockin on Heavens Door
#
#                                            description  \
# 0    "I wrote it. I didn't fail. It was straight," ...
# 13   In April 1962, at Gerde's Folk City in New Yor...
# 82   When Dylan introduced "Tangled Up in Blue" ons...
# 91   "I wanted to write a big song, some kind of th...
# 158  Three years had passed since his last studio a...
#
#                                    appears on     artist writers  \
# 0             Highway 61 Revisited (Columbia)  Bob Dylan   Dylan
# 13     The Freewheelin' Bob Dylan (Columbia)   Bob Dylan   Dylan
# 82            Blood on the Tracks (Columbia)   Bob Dylan   Dylan
# 91   The Times They Are A-Changin' (Columbia)  Bob Dylan   Dylan
# 158            The Essential Bob Dylan (Sony)  Bob Dylan   Dylan
#
# ...

# %%
elvis_songs_df = df.loc[df["artist"] == 'Elvis Presley', :]
elvis_songs_df.head()
# Out:
#                title                                        description  \
# 18         Hound Dog  "Hound Dog" was a hit before Elvis Presley san...
# 44  Heartbreak Hotel  When RCA Records signed "hillbilly cat" Presle...
# 59  Suspicious Minds  When Moman presented this song to Presley in 1...
# 73     Mystery Train  "Mystery Train" is one of Presley's most haunt...
# 83    Jailhouse Rock  Songwriters Leiber and Stoller had already pen...
#
#                  appears on         artist  \
# 18  Elvis 30 #1 Hits (RCA)   Elvis Presley
# 44  Elvis 30 #1 Hits (RCA)   Elvis Presley
# 59  Elvis 30 #1 Hits (RCA)   Elvis Presley
# 73           Sunrise (RCA)   Elvis Presley
# 83  Elvis 30 #1 Hits (RCA)   Elvis Presley
#
#                                    writers  \
# 18              Jerry Leiber, Mike Stoller
# 44  Mae Boren Axton, Tommy Durden, Presley
# 59                              Mark James
# 73             Junior Parker, Sam Phillips
# 83              Jerry Leiber, Mike Stoller
#
# ...

# %%
stones_songs_df = df.loc[df["artist"] == 'The Rolling Stones', :]
stones_songs_df.head()
# Out:
#                               title  \
# 1    (I Can't Get No) Satisfaction'
# 31           Sympathy for the Devil
# 37                    Gimme Shelter
# 174                  Paint it Black
# 307                     Wild Horses
#
#                                            description  \
# 1    "It's the riff heard round the world," says St...
# 31   The inspiration for this hellish detour came f...
# 37   The Stones channeled the emotional wreckage of...
# 174  Brian Jones plucked the haunting sitar melody ...
# 307  Richards wrote this acoustic ballad about leav...
#
#                     appears on              artist  \
# 1     Out of Our Heads (ABKCO)  The Rolling Stones
# 31   Beggar's Banquet (ABKCO)   The Rolling Stones
# 37       Let It Bleed (ABKCO)   The Rolling Stones
# 174          Aftermath (ABKCO)  The Rolling Stones
# 307    Sticky Fingers (Virgin)  The Rolling Stones
#
#                          writers            producer    streak position  \
# ...

# %%
beachboys_songs_df = df.loc[df["artist"] == 'The Beach Boys', :]
beachboys_songs_df.head()
# Out:
#                 title                                        description  \
# 5     Good Vibrations  "It scared me, the word 'vi-brations,'" Brian ...
# 24     God Only Knows  "It's very emotional, always a bit of a choker...
# 78   California Girls  The first time Wilson took acid, he sat at the...
# 172   Dont Worry Baby  Wilson, who listened to the Ronettes' "Be My B...
# 236          Caroline  Wilson ditched the other Beach Boys and used s...
#
#                                             appears on          artist  \
# 5                   Smiley Smile/Wild Honey (Capitol)   The Beach Boys
# 24                               Pet Sounds (Capitol)   The Beach Boys
# 78   Sounds of Summer: The Very Best of the Beach B...  The Beach Boys
# 172                         Sounds of Summer (Capitol)  The Beach Boys
# 236                               Pet Sounds (Capitol)  The Beach Boys
#
#                            writers producer    streak position    month   year
# ...

# %%
U2_songs_df = df.loc[df["artist"] == 'U2', :]
U2_songs_df.head()
# Out:
#                                         title  \
# 35                                        One
# 57   I Still Havent Found What Im Looking For
# 190                       Moment of Surrender
# 278                      Sunday Bloody Sunday
# 305                             Beautiful Day
#
#                                            description  \
# 35   Achtung Baby was the album on which U2 traded ...
# 57   "The music that really turns me on is either r...
# 190  The most devastating U2 ballad since "One" set...
# 278  This rallying cry set to a military beat was i...
# 305  The song that re-established U2 as the worldâ...
#
#                                      appears on artist  \
# 35                       Achtung Baby (Island)      U2
# 57                    The Joshua Tree (Island)      U2
# 190         No Line on the Horizon (Interscope)     U2
# 278                                War (Island)     U2
# 305  All That You Canât Leave Behind (Island)     U2
#
# ...

# %%
zeppelin_songs_df = df.loc[df["artist"] == 'Led Zeppelin', :]
zeppelin_songs_df.head()
# Out:
#                   title                                        description  \
# 30   Stairway to Heaven  All epic anthems must measure themselves again...
# 75     Whole Lotta Love  The members of Led Zeppelin first got their so...
# 250           Black Dog  A dog meandering the grounds outside Zeppelinâ...
# 322        Heartbreaker  "Heartbreaker," like much of Led Zeppelin II, ...
# 410           Ramble On  Groupies and The Lord of the Rings inspired "R...
#
#                       appears on        artist  \
# 30   Led Zeppelin IV (Atlantic)   Led Zeppelin
# 75   Led Zeppelin II (Atlantic)   Led Zeppelin
# 250   Led Zeppelin IV (Atlantic)  Led Zeppelin
# 322   Led Zeppelin II (Atlantic)  Led Zeppelin
# 410   Led Zeppelin II (Atlantic)  Led Zeppelin
#
#                                                writers    producer  \
# 30                            Jimmy Page, Robert Plant        Page
# 75                          Willie Dixon, Led Zeppelin  Jimmy Page
# ...
